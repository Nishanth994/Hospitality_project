# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #    1. Data Import and Data Exploration

# %% [markdown]
# ### Datasets
# We have 5 csv file
#
#    - dim_date.csv
#    - dim_hotels.csv
#    - dim_rooms.csv
#    - fact_aggregated_bookings
#    - fact_bookings.csv

# %% [markdown]
# **Read_data**

# %%
df_date = pd.read_csv('C:\\Users\\KBINM20373\\Documents\\resume projects\\input-files-1\\Input Files\\dim_date.csv')
df_hotels = pd.read_csv('C:\\Users\\KBINM20373\\Documents\\resume projects\\input-files-1\\Input Files\\dim_hotels.csv')
df_rooms = pd.read_csv('C:\\Users\\KBINM20373\\Documents\\resume projects\\input-files-1\\Input Files\\dim_rooms.csv')
df_agg_bookings = pd.read_csv('C:\\Users\\KBINM20373\\Downloads\\64101194a2364\\source-code\\3_project_hospitality_analysis\\datasets\\fact_aggregated_bookings.csv')
df_bookings = pd.read_csv('C:\\Users\\KBINM20373\\Downloads\\64101194a2364\\source-code\\3_project_hospitality_analysis\\datasets\\fact_bookings.csv')

# %% [markdown]
# **Explore bookings data**

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


value_counts = df_bookings['booking_platform'].value_counts()
ax = value_counts.plot(kind='barh', color='green')


for i, count in enumerate(value_counts):
    ax.text(count, i, str(count), ha='left', va='center')  # Adjusted the coordinates and alignment


plt.xlabel('Number of Bookings')
plt.ylabel('Booking Platform')
plt.title('Bookings by Platform')

plt.show()

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# **Read data**

# %%
df_hotels = pd.read_csv('C:\\Users\\KBINM20373\\Documents\\resume projects\\input-files-1\\Input Files\\dim_hotels.csv')

# %%
df_hotels.head(5)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values()
# Out:
# city
# Delhi        5
# Hyderabad    6
# Bangalore    6
# Mumbai       8
# Name: count, dtype: int64

# %%
value_counts = df_hotels['city'].value_counts()

ax = value_counts.plot(kind='bar', color='red')

for i, count in enumerate(value_counts):
    ax.text(i, count, str(count), ha='center', va='bottom')


plt.xlabel('City')
plt.ylabel('Number of Bookings')
plt.title('Bookings by City')

# Show the plot
plt.show()

# %%
#Explore df_agg_bookings data
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559     01-May-22           RT1                   25        30
# 1        19562     01-May-22           RT1                   28        30
# 2        19563     01-May-22           RT1                   23        30
# 3        17558     01-May-22           RT1                   13        19
# 4        16558     01-May-22           RT1                   18        19

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %%
#Find out unique property ids in aggregate bookings dataset
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560], dtype=int64)

# %%
#Find out total bookings per property_id
df_agg_bookings.groupby('property_id')['successful_bookings'].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings[df_agg_bookings.capacity==df_agg_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# ***
# ### ==> 2. Data Cleaning
# ***

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings=df_bookings[df_bookings.no_guests>0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %% [markdown]
# **(2) Outlier removal in revenue generated**

# %%
avg,std=df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()

# %%
df_bookings.revenue_generated.describe()
# Out:
# count    1.345780e+05
# mean     1.537804e+04
# std      9.304015e+04
# min      6.500000e+03
# 25%      9.900000e+03
# 50%      1.350000e+04
# 75%      1.800000e+04
# max      2.856000e+07
# Name: revenue_generated, dtype: float64

# %%
higher_limit=avg+3*std
higher_limit
# Out:
# 294498.50173198653

# %%
lower_limit=avg-3*std
lower_limit             # revenue generated can't be in negative
# Out:
# -263742.4278566132

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<=higher_limit]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
avg_,std_=df_bookings.revenue_realized.mean(),df_bookings.revenue_realized.std()
avg_,std_
# Out:
# (12695.983585117372, 6927.791692242509)

# %%
higher_limit=avg_+3*std_
higher_limit
# Out:
# 33479.3586618449

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %% [markdown]
# One observation we can have in above dataframe is that all rooms are RT4 which means presidential suit. Now since RT4 is a luxurious room it is likely their rent will be higher. To make a fair analysis, we need to do data analysis only on RT4 room types

# %%
df_bookings[df_bookings.room_category=='RT4'].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
23439+3*9048
# Out:
# 50583

# %% [markdown]
# Here higher limit comes to be 50583 and in our dataframe above we can see that max value for revenue realized is 45220. Hence we can conclude that there is no outlier and we don't need to do any data cleaning on this particular column

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# Total values in our dataframe is 134576. Out of that 77899 rows has null rating. Since there are many rows with null rating, we should not filter these values. Also we should not replace this rating with a median or mean rating etc

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# Occ Pct                0
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_agg_bookings.capacity.mean(),df_agg_bookings.capacity.median()
# Out:
# (25.280495759947815, 25.0)

# %%
df_agg_bookings.capacity.fillna(df_agg_bookings.capacity.median(),inplace=True)

# %%
df_agg_bookings.loc[[8,14]]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22      25.0
# 14        17562      1-May-22           RT1                   12      25.0

# %% [markdown]
# **In aggregate bookings find out records that have successful_bookings value greater than capacity. Filter those records**

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings=df_agg_bookings[df_agg_bookings.successful_bookings<=df_agg_bookings.capacity]

# %% [markdown]
# ***
# ### ==> 3. Data Transformation
# ***

# %%
# used lambda function here
df_agg_bookings["Occ Pct"]=df_agg_bookings.successful_bookings/df_agg_bookings.capacity
df_agg_bookings["Occ Pct"]=df_agg_bookings["Occ Pct"].apply(lambda x: round(x*100,2))
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 4           16558      1-May-22           RT1                   18      19.0
# 5           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       Occ Pct
# 0       83.33
# ...

# %%
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 4           16558      1-May-22           RT1                   18      19.0
# 5           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       Occ Pct
# 0       83.33
# ...

# %%
df_agg_bookings.groupby("room_category")['Occ Pct'].mean().round(2)
# Out:
# room_category
# RT1    57.88
# RT2    58.01
# RT3    58.03
# RT4    59.28
# Name: Occ Pct, dtype: float64

# %% [markdown]
# I don't understand RT1, RT2 etc. Print room categories such as Standard, Premium, Elite etc along with average occupancy percentage

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df=pd.merge(df_agg_bookings,df_rooms,left_on='room_category',right_on='room_id')
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           16558      1-May-22           RT1                   18      19.0
# 4           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9187        16563     31-Jul-22           RT4                   13      18.0
# 9188        16559     31-Jul-22           RT4                   13      18.0
# 9189        17558     31-Jul-22           RT4                    3       6.0
# 9190        19563     31-Jul-22           RT4                    3       6.0
# 9191        17561     31-Jul-22           RT4                    3       4.0
#
#       Occ Pct room_id    room_class
# ...

# %%
df.groupby("room_class")["Occ Pct"].mean().round(2)
# Out:
# room_class
# Elite           58.01
# Premium         58.03
# Presidential    59.28
# Standard        57.88
# Name: Occ Pct, dtype: float64

# %%
df.drop("room_id",axis=1,inplace=True)

# %%
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           16558      1-May-22           RT1                   18      19.0
# 4           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9187        16563     31-Jul-22           RT4                   13      18.0
# 9188        16559     31-Jul-22           RT4                   13      18.0
# 9189        17558     31-Jul-22           RT4                    3       6.0
# 9190        19563     31-Jul-22           RT4                    3       6.0
# 9191        17561     31-Jul-22           RT4                    3       4.0
#
#       Occ Pct    room_class
# ...

# %% [markdown]
# **2. Print average occupancy rate per city**

# %%
df=pd.merge(df,df_hotels,on='property_id',how ='inner')

# %%
df.groupby('city')["Occ Pct"].mean()
# Out:
# city
# Bangalore    56.332376
# Delhi        61.507341
# Hyderabad    58.120652
# Mumbai       57.902319
# Name: Occ Pct, dtype: float64

# %%
df.groupby('city')["Occ Pct"].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **3. When was the occupancy better? Weekday or Weekend?**

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df=pd.merge(df,df_date,left_on='check_in_date',right_on='date')

# %%
df.groupby("day_type")["Occ Pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: Occ Pct, dtype: float64

# %% [markdown]
# **4: In the month of June, what is the occupancy for different cities**

# %%
df_jun22=df[df["mmm yy"]=='Jun 22']

# %%
df.groupby('city')["Occ Pct"].mean().round(2)
# Out:
# city
# Bangalore    55.18
# Delhi        60.40
# Hyderabad    56.90
# Mumbai       56.78
# Name: Occ Pct, dtype: float64

# %%
df.groupby('city')["Occ Pct"].mean().round(2).plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
#  **5.We got new data for the month of august. Append that to existing data**

# %%
df_august=pd.read_csv('C:\\Users\\KBINM20373\\Downloads\\64101194a2364\\source-code\\3_project_hospitality_analysis\\datasets\\new_data_august.csv')

# %%
latest_df = pd.concat([df, df_august], ignore_index = True, axis = 0)
latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6494        17562     31-Jul-22           RT2                   12      30.0
# 6495        17562     31-Jul-22           RT3                   14      27.0
# 6496        17562     31-Jul-22           RT4                    2       6.0
# 6497        16559     01-Aug-22           RT1                   30      30.0
# 6498        19562     01-Aug-22           RT1                   21      30.0
# 6499        19563     01-Aug-22           RT1                   23      30.0
# 6500        19558     01-Aug-22           RT1                   30      40.0
# 6501        19560     01-Aug-22           RT1                   20      26.0
# 6502        17561     01-Aug-22           RT1                   18      26.0
# 6503        17564     01-Aug-22           RT1                   10      16.0
#
#       Occ Pct    room_class  property_name  category       city       date  \
# ...

# %%
pd.concat()
